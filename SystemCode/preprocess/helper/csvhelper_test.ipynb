# %%
from csvhelper import read

# %%
#sample

header = [
    "ingredient",
    "recipe_id",
    "publisher",
    'source_url', 
    'image_url', 
    'social_rank', 
    'publisher_url', 
    'title', 
    'sum_cal', 
    'sum_fat', 
    'sum_carb', 
    'sum_protein'
]
read("../data/recipe.csv", header)
# Out:
# [{'ingredient': 'carrot',
#   'recipe_id': '35169',
#   'publisher': 'Closet Cooking',
#   'source_url': 'http://www.closetcooking.com/2011/11/buffalo-chicken-chowder.html',
#   'image_url': 'http://forkify-api.herokuapp.com/images/Buffalo2BChicken2BChowder2B5002B0075c131caa8.jpg',
#   'social_rank': '100.0',
#   'publisher_url': 'http://closetcooking.com',
#   'title': 'Buffalo Chicken Chowder',
#   'sum_cal': '1716.5044105',
#   'sum_fat': '36.712325320000005',
#   'sum_carb': '169.4496',
#   'sum_protein': '172.05543469999998'},
#  {'ingredient': 'carrot',
#   'recipe_id': '35171',
#   'publisher': 'Closet Cooking',
#   'source_url': 'http://www.closetcooking.com/2011/08/buffalo-chicken-grilled-cheese-sandwich.html',
#   'image_url': 'http://forkify-api.herokuapp.com/images/Buffalo2BChicken2BGrilled2BCheese2BSandwich2B5002B4983f2702fe4.jpg',
#   'social_rank': '100.0',
#   'publisher_url': 'http://closetcooking.com',
#   'title': 'Buffalo Chicken Grilled Cheese Sandwich',
# ...

# %%
import pandas as pd
df = pd.read_csv("../data/recipe.csv")

df.keys().tolist()
# Out:
# ['query',
#  'recipe_id',
#  'publisher',
#  'source_url',
#  'image_url',
#  'social_rank',
#  'publisher_url',
#  'title',
#  'sum_cal',
#  'sum_fat',
#  'sum_carb',
#  'sum_protein']
